# %%
import pandas as pd

# %%
sepsis_df = pd.read_csv("data/dataSepsis.csv", sep=";")

# %%
sepsis_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36302 entries, 0 to 36301
# Data columns (total 41 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   HR                35506 non-null  float64
#  1   O2Sat             34736 non-null  float64
#  2   Temp              17101 non-null  float64
#  3   SBP               34617 non-null  float64
#  4   MAP               34846 non-null  float64
#  5   DBP               27917 non-null  float64
#  6   Resp              33890 non-null  float64
#  7   EtCO2             1613 non-null   float64
#  8   BaseExcess        7184 non-null   float64
#  9   HCO3              16984 non-null  float64
#  10  FiO2              6427 non-null   float64
#  11  pH                9221 non-null   float64
#  12  PaCO2             8430 non-null   float64
#  13  SaO2              4335 non-null   float64
#  14  AST               10391 non-null  float64
#  15  BUN               32526 non-null  float64
# ...

# %%
sepsis_df = sepsis_df.drop(columns=['Unit1', 'Unit2'])

# %%
sepsis_df
# Out:
#           HR  O2Sat   Temp    SBP    MAP   DBP  Resp  EtCO2  BaseExcess  HCO3  \
# 0      103.0   90.0    NaN    NaN    NaN   NaN  30.0    NaN        21.0  45.0
# 1       58.0   95.0  36.11  143.0   77.0  47.0  11.0    NaN         NaN  22.0
# 2       91.0   94.0  38.50  133.0   74.0  48.0  34.0    NaN         NaN  31.0
# 3       92.0  100.0    NaN    NaN    NaN   NaN   NaN    NaN         NaN  29.0
# 4      155.5   94.5    NaN  147.5  102.0   NaN  33.0    NaN       -12.0  13.0
# ...      ...    ...    ...    ...    ...   ...   ...    ...         ...   ...
# 36297   59.0   95.0    NaN  154.0  110.0  82.0  14.0    NaN         NaN   NaN
# 36298   81.0   99.0    NaN  122.0   71.0  58.0  20.0    NaN         NaN   NaN
# 36299   76.0   96.0  36.30  118.0   79.0  68.0  14.0    NaN         NaN   NaN
# 36300   76.0   89.0    NaN  145.0  102.0  74.0   NaN    NaN         NaN   NaN
# 36301   98.0   99.0    NaN  152.0  119.0  84.0  18.0    NaN         NaN   NaN
#
# ...

# %%
df_datatypes = pd.DataFrame(sepsis_df.dtypes)
df_non_nulls = pd.DataFrame(sepsis_df.count())

# %%
sepsis_df['MAP'].count()
# Out:
# 34846

# %%
count_dict = dict(sepsis_df.count())

# %%
def column_val_counter(count_dict):
    for key,value in count_dict.items():
        return key,value

# %%
column_val_counter(count_dict)
# Out:
# ('HR', 35506)

# %%
count_dict
# Out:
# {'HR': 35506,
#  'O2Sat': 34736,
#  'Temp': 17101,
#  'SBP': 34617,
#  'MAP': 34846,
#  'DBP': 27917,
#  'Resp': 33890,
#  'EtCO2': 1613,
#  'BaseExcess': 7184,
#  'HCO3': 16984,
#  'FiO2': 6427,
#  'pH': 9221,
#  'PaCO2': 8430,
#  'SaO2': 4335,
#  'AST': 10391,
#  'BUN': 32526,
#  'Alkalinephos': 10269,
#  'Calcium': 28623,
#  'Chloride': 17365,
#  'Creatinine': 32260,
#  'Bilirubin_direct': 1132,
#  'Glucose': 33257,
#  'Lactate': 4134,
#  'Magnesium': 27671,
#  'Phosphate': 21768,
#  'Potassium': 32709,
#  'Bilirubin_total': 10313,
#  'TroponinI': 3746,
#  'Hct': 32180,
#  'Hgb': 31816,
#  'PTT': 13875,
#  'WBC': 31460,
#  'Fibrinogen': 2141,
#  'Platelets': 31469,
#  'Age': 36302,
#  'Gender': 36302,
#  'HospAdmTime': 36302,
#  'ICULOS': 36302,
#  'isSepsis': 36302}

# %%
sepsis_non_nulls = pd.DataFrame.from_dict(count_dict, orient='index', columns=['non-nulls']).reset_index(level=0)

# %%
sepsis_non_nulls.rename(columns={'index':'columns'}, inplace=True)

# %%
sepsis_non_nulls
# Out:
#              columns  non-nulls
# 0                 HR      35506
# 1              O2Sat      34736
# 2               Temp      17101
# 3                SBP      34617
# 4                MAP      34846
# 5                DBP      27917
# 6               Resp      33890
# 7              EtCO2       1613
# 8         BaseExcess       7184
# 9               HCO3      16984
# 10              FiO2       6427
# 11                pH       9221
# 12             PaCO2       8430
# 13              SaO2       4335
# 14               AST      10391
# 15               BUN      32526
# 16      Alkalinephos      10269
# 17           Calcium      28623
# 18          Chloride      17365
# 19        Creatinine      32260
# 20  Bilirubin_direct       1132
# 21           Glucose      33257
# 22           Lactate       4134
# 23         Magnesium      27671
# 24         Phosphate      21768
# 25         Potassium      32709
# 26   Bilirubin_total      10313
# 27         TroponinI       3746
# ...

# %%
sepsis_non_nulls.sort_values(by=['non-nulls'], ascending = False)
# Out:
#              columns  non-nulls
# 38          isSepsis      36302
# 34               Age      36302
# 37            ICULOS      36302
# 36       HospAdmTime      36302
# 35            Gender      36302
# 0                 HR      35506
# 4                MAP      34846
# 1              O2Sat      34736
# 3                SBP      34617
# 6               Resp      33890
# 21           Glucose      33257
# 25         Potassium      32709
# 15               BUN      32526
# 19        Creatinine      32260
# 28               Hct      32180
# 29               Hgb      31816
# 33         Platelets      31469
# 31               WBC      31460
# 17           Calcium      28623
# 5                DBP      27917
# 23         Magnesium      27671
# 24         Phosphate      21768
# 18          Chloride      17365
# 2               Temp      17101
# 9               HCO3      16984
# 30               PTT      13875
# 14               AST      10391
# 26   Bilirubin_total      10313
# ...

# %%
 list(sepsis_non_nulls[sepsis_non_nulls['non-nulls'] >= 10000]['columns'])
# Out:
# ['HR',
#  'O2Sat',
#  'Temp',
#  'SBP',
#  'MAP',
#  'DBP',
#  'Resp',
#  'HCO3',
#  'AST',
#  'BUN',
#  'Alkalinephos',
#  'Calcium',
#  'Chloride',
#  'Creatinine',
#  'Glucose',
#  'Magnesium',
#  'Phosphate',
#  'Potassium',
#  'Bilirubin_total',
#  'Hct',
#  'Hgb',
#  'PTT',
#  'WBC',
#  'Platelets',
#  'Age',
#  'Gender',
#  'HospAdmTime',
#  'ICULOS',
#  'isSepsis']

# %% [markdown]
# Check for rows with significant amount of missing data.

# %% [markdown]
# ### Important Factors for Sepsis Identification
# 1. Heart Rate
# 2. O2Sat
# 3. Temp
# 4. SBP
# 5. MAP
# 6. DBP
# 7. Resp
# 8. Lactate
# 9. WBC
# 10. PaCO2

# %%
# factors = ['HR', 'O2Sat', 'Temp', 'SBP', 'MAP', 'DBP', 'Resp', 'Lactate', 'WBC', 'PaCO2', 'isSepsis']

# factors =  list(sepsis_non_nulls[sepsis_non_nulls['non-nulls'] >= 21769]['columns'])
# sepsis_df[factors].dropna()

factors =  list(sepsis_non_nulls[sepsis_non_nulls['non-nulls'] >= 27917]['columns'])
sepsis_df[factors].dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16621 entries, 1 to 36298
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   HR           16621 non-null  float64
#  1   O2Sat        16621 non-null  float64
#  2   SBP          16621 non-null  float64
#  3   MAP          16621 non-null  float64
#  4   DBP          16621 non-null  float64
#  5   Resp         16621 non-null  float64
#  6   BUN          16621 non-null  float64
#  7   Calcium      16621 non-null  float64
#  8   Creatinine   16621 non-null  float64
#  9   Glucose      16621 non-null  float64
#  10  Potassium    16621 non-null  float64
#  11  Hct          16621 non-null  float64
#  12  Hgb          16621 non-null  float64
#  13  WBC          16621 non-null  float64
#  14  Platelets    16621 non-null  float64
#  15  Age          16621 non-null  float64
#  16  Gender       16621 non-null  int64
#  17  HospAdmTime  16621 non-null  float64
# ...

# %%
sepsis_df = sepsis_df[factors].dropna()

# %%
sepsis_df
# Out:
#          HR  O2Sat    SBP    MAP   DBP  Resp    BUN  Calcium  Creatinine  \
# 1      58.0   95.0  143.0   77.0  47.0  11.0  100.0     7.90        2.50
# 2      91.0   94.0  133.0   74.0  48.0  34.0   30.0    10.90        0.90
# 5      73.0   99.0  100.0   67.0  49.5  16.5   28.0     7.40        1.20
# 8      89.0  100.0  141.0   85.0  57.0  17.0    9.0     8.40        0.70
# 16     98.0   94.0   95.0   62.0  45.0  15.0   11.0     7.40        0.50
# ...     ...    ...    ...    ...   ...   ...    ...      ...         ...
# 36293  74.0   97.0  120.0   72.0  44.0  12.0   14.0     7.50        0.79
# 36294  91.0   94.0  136.0   90.0  63.0  21.0   37.0     9.20        9.93
# 36296  73.0  100.0  120.0   78.0  58.0  14.5   11.0     4.79        1.13
# 36297  59.0   95.0  154.0  110.0  82.0  14.0    9.0     8.80        0.81
# 36298  81.0   99.0  122.0   71.0  58.0  20.0    8.0     8.80        0.58
#
#        Glucose  Potassium   Hct   Hgb   WBC  Platelets    Age  Gender  \
# ...

# %%
sepsis_df.to_csv('sepsis_df.csv', index=False)
